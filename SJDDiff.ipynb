# %%
import pandas as pd

# %%
dfcvc = pd.read_csv('CVC-SJD-2223.csv')
dfcvc.head()
# Out:
#   Course Code                     Course Name Section    CRN Start Date  \
# 0       BUS35      Introduction to Leadership       1  32244    1/24/22
# 1       BUS12  Latinx Culture/Entrepreneurshi       1  32243    1/24/22
# 2       BUS86        Intro to Warehouse Mgmt.      1A  30584    3/21/22
# 3      BUS94F        Customer Serv Strategies       1  30940    4/11/22
# 4      BUS94C            The New Entrepreneur       1  30939    4/11/22
#
#   End Date         Term           Teaching College          Professors  Units  \
# 0  5/15/22  Spring 2022  San Joaquin Delta College      Gillian Murphy    3.0
# 1  5/15/22  Spring 2022  San Joaquin Delta College        Gene Acevedo    3.0
# 2  5/15/22  Spring 2022  San Joaquin Delta College   Johnathan Cardiel    3.0
# 3  5/15/22  Spring 2022  San Joaquin Delta College   Martha Villarreal    1.0
# 4  5/15/22  Spring 2022  San Joaquin Delta College  Andrzej Kobylanski    1.0
#
#   Visible Filter Applied
# 0     Yes            Yes
# ...

# %%
dfcvc.shape
# Out:
# (999, 12)

# %%
dfsjd = pd.read_csv('SJD-SJD-2223-2.csv')
dfsjd.head()
# Out:
#    Term Acad Org Session                Long Name Campus Location Career  \
# 0  2223     ASBT     8W2          8 Week - Second   INET     ONLN   UGRD
# 1  2223     ASBT       1  Regular Start Full Term   INET     ONLN   UGRD
# 2  2223     ASBT       1  Regular Start Full Term   INET     ONLN   UGRD
# 3  2223     ASBT       1  Regular Start Full Term   INET     ONLN   UGRD
# 4  2223     ASBT       1  Regular Start Full Term   INET     ONLN   UGRD
#
#    Course ID  Offer Nbr Subject  ...          ID     Display Name        Role  \
# 0      10449          1   AGBUS  ...   986218354  Dustin Sperling  Prim Instr
# 1      10452          1   AGBUS  ...   986218354  Dustin Sperling  Prim Instr
# 2      10455          1   AGBUS  ...   986218354  Dustin Sperling  Prim Instr
# 3      10517          1   AH SC  ...  1000027357  Jessica Cardoso  Prim Instr
# 4      10517          1   AH SC  ...  1000027357  Jessica Cardoso  Prim Instr
#
# ...

# %%
dfsjd.shape
# Out:
# (923, 52)

# %%
mergesjd= pd.merge(dfcvc, dfsjd, left_on = 'CRN', right_on = 'Class Nbr', how='outer')

# %%
mergesjdexport = mergesjd.to_csv('mergesjd.csv')
